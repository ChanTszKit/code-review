# %% [markdown]
# ### Import packages

# %%
import pickle

# %% [markdown]
# ### Open .pkl

# %%
file_name = "CP_program-v01.pkl"

file = open(file_name, 'rb')

# %% [markdown]
# ### Read .pkl

# %%
var = pickle.load(file)

# %%
var
# Out:
# ({'Bar': {'Bar New': 0,
#    'Bar Continue': 1,
#    'Bar <PAD>': 2,
#    'Bar <MASK>': 3,
#    'Bar <EOS>': 4,
#    'Bar <ABS>': 5,
#    'Bar <BOS>': 6},
#   'Position': {'Position 1/24': 0,
#    'Position 2/24': 1,
#    'Position 3/24': 2,
#    'Position 4/24': 3,
#    'Position 5/24': 4,
#    'Position 6/24': 5,
#    'Position 7/24': 6,
#    'Position 8/24': 7,
#    'Position 9/24': 8,
#    'Position 10/24': 9,
#    'Position 11/24': 10,
#    'Position 12/24': 11,
#    'Position 13/24': 12,
#    'Position 14/24': 13,
#    'Position 15/24': 14,
#    'Position 16/24': 15,
#    'Position 17/24': 16,
#    'Position 18/24': 17,
#    'Position 19/24': 18,
#    'Position 20/24': 19,
#    'Position 21/24': 20,
#    'Position 22/24': 21,
#    'Position 23/24': 22,
#    'Position 24/24': 23,
#    'Position <PAD>': 24,
#    'Position <MASK>': 25,
#    'Position <EOS>': 26,
#    'Position <ABS>': 27,
#    'Position <BOS>': 28},
#   'Pitch': {'Pitch 22': 0,
#    'Pitch 23': 1,
# ...
